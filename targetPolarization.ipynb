# %%
# %run tools/tpol_tools.ipynb

# %%
df = get_table("/volatile/clas12/users/gmat/clas12analysis.sidis.data/rgc/tpol/data/8c.4.0/",16500,17246,"ND3")
# Out:
# Completed run: 17227
# Completed run: 17237
# Completed run: 17240
# Completed run: 17245
# Completed run: 17246

# %%
multigraph(df,0.88)
# Out:
# [17227. 17237. 17240. 17245. 17246.]
# 0.300+/-0.004
# 0.2912+/-0.0016
# 0.2865+/-0.0014
# 0.2792+/-0.0020
# 0.334+/-0.026
# 0.3008+/-0.0026
# 0.2958+/-0.0018
# 0.2881+/-0.0016
# 0.2779+/-0.0017
# 0.2834+/-0.0030
# 0.310+/-0.005
# 0.2987+/-0.0023
# 0.2970+/-0.0020
# 0.2879+/-0.0020
# 0.2836+/-0.0020
# 0.2815+/-0.0028
# 0.306+/-0.022
# 0.3022+/-0.0029
# 0.2986+/-0.0025
# 0.2967+/-0.0024
# 0.2902+/-0.0024
# 0.2888+/-0.0025
# 0.2876+/-0.0032
# 0.309+/-0.005
# 0.3091+/-0.0034
# 0.3020+/-0.0035
# 0.299+/-0.004
# 0.288+/-0.004
# 0.290+/-0.004
# 0.294+/-0.007
# 0.295+/-0.010
# 0.311+/-0.005
# 0.309+/-0.006
# 0.312+/-0.006
# 0.298+/-0.007
# 0.299+/-0.009
# 0.298+/-0.016
# 0.303+/-0.007
# 0.312+/-0.007
# 0.313+/-0.008
# 0.311+/-0.009
# 0.306+/-0.018
# 0.285+/-0.010
# 0.303+/-0.010
# 0.302+/-0.011
# 0.297+/-0.015
# 0.276+/-0.017
# 0.309+/-0.014
# 0.308+/-0.017
# 0.295+/-0.030
# 0.293+/-0.022
# 0.306+/-0.032
# 0.31+/-0.08
# 0.28+/-0.04
# 0.300+/-0.004
# 0.2912+/-0.0016
# 0.2865+/-0.0014
# ...
